# %% [markdown]
# <a href="https://colab.research.google.com/github/Vachana7/DAV-LAB/blob/main/theory_corelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
from scipy import stats

tips = sns.load_dataset("tips")

print(tips["total_bill"].corr(tips["tip"]))

smokers = tips[tips.smoker == "Yes"]["tip"]
non_sm = tips[tips.smoker == "No"]["tip"]

t, p = stats.ttest_ind(smokers, non_sm)

print(f"t={t:.3f}, p={p:.3f}")

print("Reject H0?", p < 0.05)
# Out:
# 0.6757341092113641
# t=0.092, p=0.927
# Reject H0? False
