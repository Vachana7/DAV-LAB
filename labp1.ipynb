# %% [markdown]
# <a href="https://colab.research.google.com/github/Vachana7/DAV-LAB/blob/main/labp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

a = np.array([37, 66, 78, 55, 46])

print('Array is', a)
print('Mean is', a.mean())
print('Median is', np.median(a))
print('Reshaped 2D:\n', a.reshape(5, 1))
print('Sliced array', a[1:4])

data = {
    'Name': ['Vachana', 'Thrisha', 'Vaishnavi', 'Varenya'],
    'Marks': [55, 86, 37, 93],
    'Branch': ['CSE', 'ECE', 'ISE', 'AIML']
}

df = pd.DataFrame(data)

print('First two rows:\n', df.iloc[0:2])
print('Marks column:\n', df['Marks'])
print('Rows where marks greater than 75:\n', df[df['Marks'] > 75])
# Out:
# Array is [37 66 78 55 46]
# Mean is 56.4
# Median is 55.0
# Reshaped 2D:
#  [[37]
#  [66]
#  [78]
#  [55]
#  [46]]
# Sliced array [66 78 55]
# First two rows:
#        Name  Marks Branch
# 0  Vachana     55    CSE
# 1  Thrisha     86    ECE
# Marks column:
#  0    55
# 1    86
# 2    37
# 3    93
# Name: Marks, dtype: int64
# Rows where marks greater than 75:
#        Name  Marks Branch
# 1  Thrisha     86    ECE
# 3  Varenya     93   AIML
